# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Read the data set to python environment

# %%
data=pd.read_csv("/content/diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# 2. Display Columns in the data set

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# 3.Calculate the mean of each column of the data set

# %%
data.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %% [markdown]
# 4. Check for the null values present in the data set

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# 3 Numbers of meaningful visualizations using the data set

# %%
# Histogram of Blood Pressure
plt.hist(data.BloodPressure,color='green',rwidth=0.5)
plt.title('Histogram of BloodPressure')
plt.xlabel('Blood Pressure')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Scatter plot of BP Vs BMI
plt.scatter(data.BloodPressure,data.BMI,color='red',alpha=0.5,marker='*')
plt.title('Scatter Plot of Blood Pressure Vs BMI')
plt.xlabel('Blood Pressure')
plt.ylabel('BMI')
# Out:
# Text(0, 0.5, 'BMI')

# %%
# pie diagram of mean of the columns of the dataset
plt.pie(data.mean(),labels=columns,autopct='%1.2f%%')
plt.title('Pie diagram of the columns of the data set')
# Out:
# Text(0.5, 1.0, 'Pie diagram of the columns of the data set')
